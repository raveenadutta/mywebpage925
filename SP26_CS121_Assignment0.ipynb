# %% [markdown]
# <a href="https://colab.research.google.com/github/raveenadutta/mywebpage925/blob/main/SP26_CS121_Assignment0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#
# #
# # CS121
# # Assignment 0
#
# I/O, Variables, Arithmetic Expressions
#
# Write the solutions of Problems 1-3 in the code segments provided.
#
# Read ALL instructions before writing your solution.
#
# </div>

# %%
 # Name:Raveena
 # Student ID: 1064655
 # Email Address: rd37

# %% [markdown]
# ## Problem 1
# (30 points)
#
# Your CS121 class needs to create an interface to get all the students' candy consumption preferences and you were assigned to write a python code that will achieve the goal. Write a program that will ask the following questions and get the necessary inputs from a student. It will also print the total number of candies needed in the semester at the end. Assume that there are 30 days in a semester.
#
# The program should-
# 1. Ask the student for their name. Print a statement with the name.
# 2. Ask what type of candy they prefer. Print a statement with the candy name.
# 3. Ask how many pieces of candy they will eat every day. Print a statement with the number of candy they eat every day and then also print the total number of candies needed in one semester.
#
# Follow the example output. Pay attention to the formatting, they need to match exactly. You can safely assume that the students will always input the correct information.
#
# Example interaction:
#
# Program output (What your code prints):
#
# > Greetings, student. What is your name?
#
# > Nice to meet you, **Moana**
#
# > What type of candy do you prefer?
#
# > Great, you want **Almond Joy** candy.
#
# > How many pieces of candy do you think you will eat every day?
#
# > Okay, you will eat **2** pieces of **Almond Joy** every day. So, you will need **60** candies in one semester.
#
# Input (What the user types):
# > **Moana**
#
# > **Almond Joy**
#
# > **2**
#
# Note that, the values in **bold** are values that change if the input changes.
# That means, you/your code would have to replace Moana, Almond Joy, and 2 with whatever the user enters.

# %%
name = input("Greetings, student. What is your name?")
print("Nice to meet you", name)
candy= input("What type of candy do you perfer?")
print("Great, you want", candy, "candy.")
how_much= int(input("How many pieces of candy do you think you will eat every day?"))
print("Okay, you will eat", how_much, "every day." "So, you will need", how_much * 30, "candies in one semester.")
# Out:
# Greetings, student. What is your name?raveena
# Nice to meet you raveena
# What type of candy do you perfer?reeses
# Great, you want reeses candy.
# How many pieces of candy do you think you will eat every day?2
# Okay, you will eat 2 every day.So, you will need 60 candies in one semester.

# %% [markdown]
# ## Problem 2
# (30 points)
#
# You are planning to run a 5K race and you have started to practice for it. You notice that you are able to run 5K in 32 minutes 45 seconds. You know that 5K race means the total distance covered is 5 kilometers.
#
# a) How many seconds are there in 32 minutes 45 seconds? Print the result in seconds. [If you need help with the math to convert minutes to seconds, see link: https://www.youtube.com/watch?v=_QyUSOw9yno]
#
# Use the following steps to write your program:
# 1.   Use two variables to store the values 32 minutes and 45 seconds.
# 2.   Use the variable(s) in an equation to convert minutes into seconds and determine total number of seconds.
#
# [Hint: 1 minute = 60 seconds, 2 minutes 10 seconds = 2 * 60 + 10 seconds = 130 seconds]
#
# 3.   Store/assign the result in another variable ```time```.
# 4.   Print the value of the variable ```time```.
#
#
# b) There are 1.61 kilometers in a mile. How many miles are there in 5 kilometers? Print the result in miles.
# 1.   Use a variable to store the value 5 kilometers.
# 2.   Use the variable(s) in your equation to convert kilometers into miles.
# 3.   Store the result in another variable ```distance```.
# 4.   Print the value of the ```distance``` variable.
#
# c) If you run a 5 kilometer race in 32 minutes 45 seconds, what is your average speed in miles per second? Print the result in miles per second.
# 1.   Use the result variables ```time``` and ```distance``` from part (a) and part (b) to calculate the average speed.
#
# [Hint: speed = distance / time]
#
# 2.   Store the result in another variable ```speed```.
# 3.   Print the ```speed``` variable.

# %%
# Problem 2: Your code here

# %% [markdown]
# ## Problem 3
# (10 * 4 = 40 points)
#
# Using print, generate the following outputs. The symbols used are * (above 8), |, \\ (using the key right above return or enter), U, o ,/, =, _(underscore) and -(hyphen). Underscore and hyphen are on the key to the right of 0.
#
# 1. CAT (I started drawing it to help you, you can complete the rest)
#
# ```
# /\     /\
#   o   o
#  =     =
#    ---
# ```
#
# 2. TREE
#
# ```
#     *
#    ***
#   *****
#  *******
# *********
#    | |
# ```
#
# 3. MONKEY
#
# ```
#  _____
# ( o o )
#  ( U )
#   ---
# ```
# 4. Draw ONE more thing, whatever you want

# %%
# Problem 3 solution here

print("/\\     /\\")
print("  o   o")
print("=       =")
print("   ---   ")


print("    *")
print("   ***")
print("  *****")
print(" *******")
print("*********")
print("   | | " )


print("   _____")
print("  ( o o )")
print("   ( U )")
print("    ---")


print
# Out:
# /\     /\
#   o   o
# =       =
#    ---
#     *
#    ***
#   *****
#  *******
# *********
#    | |
#    _____
#   ( o o )
#    ( U )
#     ---
